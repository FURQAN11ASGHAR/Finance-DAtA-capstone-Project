# %% [markdown]
# # Finance data capstone project 📈
# In this Project we will explore stocks data information of varius US banks from 2006 to 2016. see the insights of stock info of these banks and compare them.
#
# ## 📌 Tools Used
# - Python
# - Pandas-Numpy-matplotlib-seaborn
# - Plotly Express
# - Jupyter Notebook

# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
from pandas_datareader import data,wb
# %matplotlib inline

# %%
import plotly
import yfinance as yf

# %%
import plotly.express as px

# %% [markdown]
# # Gatthering stocks data of the banks from 2006-2016

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
BAC = yf.download('BAC', start=start, end=end, auto_adjust=True)       #bankof America
C = yf.download('C', start=start, end=end, auto_adjust=True)           # Citigroup
GS = yf.download('GS', start=start, end=end, auto_adjust=True)         # Gold man Sachs
JPM = yf.download('JPM', start=start, end=end, auto_adjust=True)       # JPMorgan Chase
MS = yf.download('MS', start=start, end=end, auto_adjust=True)         # Morgan Stanley
WFC = yf.download('WFC', start=start, end=end, auto_adjust=True)       # Wells fargo Bank
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
GS
# Out:
# Price            Close        High         Low        Open   Volume
# Ticker              GS          GS          GS          GS       GS
# Date
# 2006-01-03   94.820480   95.239883   91.406449   93.223830  6188700
# 2006-01-04   93.510773   94.849905   92.988367   93.702078  4861600
# 2006-01-05   93.473999   93.680018   92.421828   92.708783  3717400
# 2006-01-06   94.798401   95.100075   93.657939   93.657939  4319600
# 2006-01-09   95.938889   96.108116   94.180365   94.548257  4723500
# ...                ...         ...         ...         ...      ...
# 2015-12-24  150.243622  150.819991  149.873100  150.078947  1107600
# 2015-12-28  149.543747  149.798995  148.078117  149.667263  1723300
# 2015-12-29  151.116425  151.651622  150.268336  150.531826  1848900
# 2015-12-30  149.864883  151.116437  149.724909  150.910590  1514300
# 2015-12-31  148.399216  150.589431  148.234541  149.164973  1773900
#
# [2517 rows x 5 columns]

# %% [markdown]
# # Restructuring data according to ease Data analysis

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                      C  \
# Price           Close       High        Low       Open    Volume       Close
# Ticker            BAC        BAC        BAC        BAC       BAC           C
# Date
# 2006-01-03  30.991041  31.056867  30.378856  30.885717  16296700  321.442688
# 2006-01-04  30.661926  31.096380  30.576351  30.938396  17757900  315.508148
# 2006-01-05  30.701422  30.826493  30.490778  30.661928  14970700  317.073364
# 2006-01-06  30.655334  30.879144  30.510516  30.806735  12599800  317.073364
# 2006-01-09  30.675074  30.918633  30.517092  30.754067  15619400  315.573334
#
#                                                          ...         MS  \
# Price             High         Low        Open   Volume  ...      Close
# Ticker               C           C           C        C  ...         MS
# Date                                                     ...
# ...

# %%
Bank_stocks=bank_stocks.droplevel('Ticker',axis=1)
Bank_stocks.head()
# Out:
#                   BAC                                                      C  \
# Price           Close       High        Low       Open    Volume       Close
# Date
# 2006-01-03  30.991041  31.056867  30.378856  30.885717  16296700  321.442688
# 2006-01-04  30.661926  31.096380  30.576351  30.938396  17757900  315.508148
# 2006-01-05  30.701422  30.826493  30.490778  30.661928  14970700  317.073364
# 2006-01-06  30.655334  30.879144  30.510516  30.806735  12599800  317.073364
# 2006-01-09  30.675074  30.918633  30.517092  30.754067  15619400  315.573334
#
#                                                          ...         MS  \
# Price             High         Low        Open   Volume  ...      Close
# Date                                                     ...
# 2006-01-03  322.029615  313.747375  319.551469  1537600  ...  31.934681
# 2006-01-04  320.203606  315.312512  318.638460  1870960  ...  31.956587
# ...

# %%
Bank_stocks.columns.set_names('Stock info', level=1, inplace=True)
Bank_stocks.columns.set_names('Bank',level=0, inplace=True)

# %%
Bank_stocks.head()
# Out:
# Bank              BAC                                                      C  \
# Stock info      Close       High        Low       Open    Volume       Close
# Date
# 2006-01-03  30.991041  31.056867  30.378856  30.885717  16296700  321.442688
# 2006-01-04  30.661926  31.096380  30.576351  30.938396  17757900  315.508148
# 2006-01-05  30.701422  30.826493  30.490778  30.661928  14970700  317.073364
# 2006-01-06  30.655334  30.879144  30.510516  30.806735  12599800  317.073364
# 2006-01-09  30.675074  30.918633  30.517092  30.754067  15619400  315.573334
#
# Bank                                                     ...         MS  \
# Stock info        High         Low        Open   Volume  ...      Close
# Date                                                     ...
# 2006-01-03  322.029615  313.747375  319.551469  1537600  ...  31.934681
# 2006-01-04  320.203606  315.312512  318.638460  1870960  ...  31.956587
# ...

# %% [markdown]
# # data analysis part

# %%
Bank_stocks.xs('Close',axis=1,level='Stock info').max()
# Out:
# Bank
# BAC     37.478706
# C      383.228333
# GS     185.153244
# JPM     53.346714
# MS      50.061161
# WFC     44.026558
# dtype: float64

# %%
#with dates
Bank_stocks.xs('Close',axis=1,level='Stock info').agg(['max', 'idxmax'])
# Out:
# Bank                    BAC                    C                   GS  \
# max               37.478706           383.228333           185.153244
# idxmax  2007-10-05 00:00:00  2006-12-27 00:00:00  2007-10-31 00:00:00
#
# Bank                    JPM                   MS                  WFC
# max               53.346714            50.061161            44.026558
# idxmax  2015-07-22 00:00:00  2007-06-14 00:00:00  2015-07-22 00:00:00

# %%
#data from a specific date to a specific date
#say i want to get 'Close ' from 2006-01-03 to 2006-01-05
Bank_stocks.xs('Close', axis=1, level='Stock info').loc['2006-01-03':'2006-01-05']
# Out:
# Bank              BAC           C         GS        JPM         MS        WFC
# Date
# 2006-01-03  30.991041  321.442688  94.820480  23.977787  31.934681  18.675646
# 2006-01-04  30.661926  315.508148  93.510773  23.839399  31.956587  18.459038
# 2006-01-05  30.701422  317.073364  93.473999  23.911606  32.044216  18.438553

# %%
Bank_stocks.loc['2006-01-03':'2006-01-05',pd.IndexSlice[:, ['Close', 'Open']]]
# Out:
# Bank              BAC                      C                     GS  \
# Stock info      Close       Open       Close        Open      Close
# Date
# 2006-01-03  30.991041  30.885717  321.442688  319.551469  94.820480
# 2006-01-04  30.661926  30.938396  315.508148  318.638460  93.510773
# 2006-01-05  30.701422  30.661928  317.073364  315.899490  93.473999
#
# Bank                         JPM                    MS                   WFC  \
# Stock info       Open      Close       Open      Close       Open      Close
# Date
# 2006-01-03  93.223830  23.977787  23.763009  31.934681  31.310335  18.675646
# 2006-01-04  93.702078  23.839399  23.935671  31.956587  32.148273  18.459038
# 2006-01-05  92.708783  23.911606  23.833384  32.044216  32.066123  18.438553
#
# Bank
# Stock info       Open
# Date
# 2006-01-03  18.500013
# 2006-01-04  18.617107
# 2006-01-05  18.441480

# %%
Bank_stocks.loc['2006-01-03':'2006-01-05']
# Out:
# Bank              BAC                                                      C  \
# Stock info      Close       High        Low       Open    Volume       Close
# Date
# 2006-01-03  30.991041  31.056867  30.378856  30.885717  16296700  321.442688
# 2006-01-04  30.661926  31.096380  30.576351  30.938396  17757900  315.508148
# 2006-01-05  30.701422  30.826493  30.490778  30.661928  14970700  317.073364
#
# Bank                                                     ...         MS  \
# Stock info        High         Low        Open   Volume  ...      Close
# Date                                                     ...
# 2006-01-03  322.029615  313.747375  319.551469  1537600  ...  31.934681
# 2006-01-04  320.203606  315.312512  318.638460  1870960  ...  31.956587
# 2006-01-05  318.116782  315.638635  315.899490  1143160  ...  32.044216
#
# Bank                                                        WFC             \
# ...

# %%
returns = pd.DataFrame()
for tick in tickers:
    returns[tick+ ' return']=Bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.005771   0.000686   -0.011598
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012031    0.016242   0.010586   -0.000158

# %% [markdown]
# **create a pairplot of the returns data frame. what stock stands out for you?**

# %% [markdown]
# # data visualization part

# %%
sns.pairplot(returns)

# %%
returns.head()
# Out:
#             BAC return  C return  GS return  JPM return  MS return  WFC return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.005771   0.000686   -0.011598
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012031    0.016242   0.010586   -0.000158

# %% [markdown]
# Qs

# %%
returns.idxmin()
# Out:
# BAC return   2009-01-20
# C return     2009-02-27
# GS return    2009-01-20
# JPM return   2009-01-20
# MS return    2008-10-09
# WFC return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC return   2009-04-09
# C return     2008-11-24
# GS return    2008-11-24
# JPM return   2009-01-21
# MS return    2008-10-13
# WFC return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# **standard deviation of all banks and figure out which bank has most riskiest deviation over the time**

# %%
returns.std()
# Out:
# BAC return    0.036659
# C return      0.038672
# GS return     0.025386
# JPM return    0.027675
# MS return     0.037717
# WFC return    0.030195
# dtype: float64

# %%
returns['2015-01-01':'2015-12-30'].std()
# Out:
# BAC return    0.016186
# C return      0.015304
# GS return     0.014058
# JPM return    0.014023
# MS return     0.016300
# WFC return    0.012562
# dtype: float64

# %% [markdown]
# **As you can see the in 2015 moragan Stanley has highest deviation although all banks are very close to each other.  Dist plot of 2015 returns of Morgan Stanley**

# %%
returns['MS return']['2015-01-01':'2015-12-30'].std()
# Out:
# 0.01630025063028219

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))
sns.distplot(returns['MS return']['2015-01-01':'2015-12-30'],color='g',bins=30,kde=True)
plt.title('MORGAN STANLEY returns of 2015')
sns.set_style("darkgrid")
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_8636\3597103522.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns['MS return']['2015-01-01':'2015-12-30'],color='g',bins=30,kde=True)

# %% [markdown]
# **dist plot of citigroup returns of year 2008**

# %%
plt.figure(figsize=(12,6))
sns.distplot(returns['C return']['2008-01-01':'2008-12-30'],kde=True,color='purple',bins=30)
plt.title('CitiGroup returns of 2008')
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_8636\143755.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns['C return']['2008-01-01':'2008-12-30'],kde=True,color='purple',bins=30)
# Text(0.5, 1.0, 'CitiGroup returns of 2008')

# %% [markdown]
# **well from the dist plots we can see that std is stretched to 0.6 which is 10 times more than morgan stanley in 2015**

# %%
for tick in tickers:
    Bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.title('Closing prices of all Banks over a period of time')

# %%
Bank_stocks.xs('Close',axis=1,level='Stock info').plot(label=tick,figsize=(12,4))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title('Closing prices of all Banks over a period of time')
# Out:
# Text(0.5, 1.0, 'Closing prices of all Banks over a period of time')

# %% [markdown]
# **now doing same with plotly for more intractive visualization**

# %%
close_prices_df = Bank_stocks.xs(key='Close', axis=1, level='Stock info')
#close_prices_df = Bank_stocks.loc[:, pd.IndexSlice[:, 'Close']]
#close_prices_df.columns = close_prices_df.columns.droplevel('Stock info')
#close_prices_df.columns.name = 'Bank' # Give the remaining level a name

# %%
px.line(
    close_prices_df,
    x=close_prices_df.index, 
    y=close_prices_df.columns, 
    title='Closing Prices of All Banks Over a Period of Time',
    labels={'value': 'Closing Price', 'index': 'Date'}, 
    height=600
)

# %%
Bank_stocks.xs('Close', axis=1, level='Stock info')
# Out:
# Bank              BAC           C          GS        JPM         MS        WFC
# Date
# 2006-01-03  30.991041  321.442688   94.820480  23.977787  31.934681  18.675646
# 2006-01-04  30.661926  315.508148   93.510773  23.839399  31.956587  18.459038
# 2006-01-05  30.701422  317.073364   93.473999  23.911606  32.044216  18.438553
# 2006-01-06  30.655334  317.073364   94.798401  24.080086  32.077072  18.546856
# 2006-01-09  30.675074  315.573334   95.938889  24.471186  32.416645  18.543930
# ...               ...         ...         ...        ...        ...        ...
# 2015-12-24  14.020794   39.868542  150.243622  51.063461  24.789011  41.797501
# 2015-12-28  13.907135   39.618931  149.543747  50.894783  24.552414  41.690750
# 2015-12-29  14.028914   40.072765  151.116425  51.423817  24.842432  42.155861
# 2015-12-30  13.842186   39.558430  149.864883  51.055786  24.598202  41.850872
# 2015-12-31  13.663578   39.142422  148.399216  50.626431  24.277658  41.446774
#
# ...

# %%
Bank_stocks.loc[:,pd.IndexSlice['BAC','Close']]
# Out:
# Date
# 2006-01-03    30.991041
# 2006-01-04    30.661926
# 2006-01-05    30.701422
# 2006-01-06    30.655334
# 2006-01-09    30.675074
#                 ...
# 2015-12-24    14.020794
# 2015-12-28    13.907135
# 2015-12-29    14.028914
# 2015-12-30    13.842186
# 2015-12-31    13.663578
# Name: (BAC, Close), Length: 2517, dtype: float64

# %% [markdown]
# **Moving Averages**
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# **Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
df2=BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean()
df2 = df2.reset_index()
df2.columns = ['Date', 'Close']
px.line(df2, x='Date', y='Close', title='30-Day Rolling Mean of BAC Closing Price (2008–2009)')

# %% [markdown]
# **Heatmap Representing a corelataion between Stocks closing prices**

# %%
sns.heatmap(Bank_stocks.xs(key='Close',axis=1,level='Stock info').corr(),annot=True)
# Out:
# <Axes: xlabel='Bank', ylabel='Bank'>

# %% [markdown]
# **clustermap Representing a cluster of corelations together**

# %%
sns.clustermap(Bank_stocks.xs(key='Close',axis=1,level='Stock info').corr(),annot=True)
